// %%
#include <iostream>

std::cout << "rubber duck debug" << std::endl;
std::cout << "                __     " << std::endl;
std::cout << "              <(o )___-" << std::endl;
std::cout << "               ( .__> /" << std::endl;
std::cout << "                `----' " << std::endl;
// Out:
// rubber duck debug
//                 __
//               <(o )___-
//                ( .__> /
//                 `----'
