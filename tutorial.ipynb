// %% [markdown]
// ## Chapter 1

// %%
#include <iostream>

std::cout << "Hello World, ";
std::cout << "Nice to meet you!";
// Out:
// Hello World, Nice to meet you!

// %%
int a;
int b;

// %%
int c, d;

// %%
// variable assignment: width was assigned as 5 intially, updated to 7 finally. Final output is 7

int width;
width = 5;

width = 7;

std::cout << width;
// Out:
// 7

// %% [markdown]
// One downside of assignment is that it requires at least two statements: one to define the variable, and one to assign the value.
//
// These two steps can be combined. When a variable is defined, you can also provide an initial value for the variable at the same time. This is called initialization. The value used to initialize a variable is called an initializer.
//
// Initialization in C++ is surprisingly complex, so we’ll present a simplified view here.
//
// There are 4 basic ways to initialize variables in C++:

// %% [markdown]
// int e;     // no initialiser
// int f = 5; // initialiser after equal sign
// int g(6); // initialiser in parenthesis
// int h{7}; // initialiser in braces

// %% [markdown]
// Copy initialization
//
// When an initializer is provided after an equals sign, this is called copy initialization. Copy initialization was inherited from the C language.
//
//
//
// Much like copy assignment, this copies the value on the right-hand side of the equals to the variable being created on the left-hand side.
//
// For simple types like int, copy initialization is efficient. However, when types get more complex, copy initialization can be inefficient.

// %% [markdown]
// int width = 5; // copy initialization of value 5 into variable width

// %% [markdown]
// Direct initialization
//
// When an initializer is provided inside parenthesis, this is called direct initialization.
//
// For simple data types (like int), copy and direct initialization are essentially the same. For more complicated types, direct initialization tends to be more efficient than copy initialization.

// %% [markdown]
// int width(5);

// %% [markdown]
// List initialization
//
// Unfortunately, direct initialization can’t be used for all types of initialization (such as initializing an object with a list of data). To provide a more consistent initialization mechanism, there’s list initialization (also sometimes called uniform initialization or brace initialization) that uses curly braces.
//
// List initialization comes in three forms:

// %% [markdown]
// int width {5}; //direct list initialisation of value 5 into variable width
// int height = {6}; // copy list initialisation of value 6 into variable height
// int dept{}; // value initialisation

// %%
int aa = 5, bb = 6; // copy initialisation
int cc(7), dd(8); // direct initialisation
int ee{9}, ff{10}; // list initialisation (preferred)

// %% [markdown]
// #### uninitialised variables and undefined behavior

// %%
// values of uninitialised variables
int x;
std::cout << x;
// Out:
// 0

// %%
std::cout << "enter your integer here:"<< "\n";
int num{};
std::cin >> num;
std::cout << "double that number:" << num * 2 << "\n";
// Out:
// enter your integer here:
//  90
// double that number:180

// %% [markdown]
// # Chapter 2 - user defined function

// %%
void doPrint(){
    std::cout << "in doPrint()";
}

// %%
doPrint()
// Out:
// in doPrint()

// %%
void myPrint()
{
    std::cout << "my print"<< "\n";
    std::cout << "123";
}

// %%
myPrint()
// Out:
// my print
// 123

// %%
void InternalCall(){
    std::cout << "here is the other function:"<< "\n";
    myPrint();
}

// %%
InternalCall()
// Out:
// here is the other function:
// my print
// 123

// %%
void getValueFromUser()
{
    std::cout << "enter input here:" << "\n";
    int num1{};
    std::cin >> num1;
    std::cout << "your input is: " << num1 << "\n";
    std::cout << "double your input is: " << num1 * 2;
}

// %%
getValueFromUser()
// Out:
// enter input here:
//  98
// your input is: 98
// double your input is: 196

// %%
getValueFromUser()
// Out:
// enter input here:
//  76
// your input is: 76
// double your input is: 152

// %%
void printInput(int x)
{
    std::cout << "the figure input is:" << x;
}

// %%
printInput(6)
// Out:
// the figure input is:6

// %%
void summation(int x, int y)
{
    std::cout << "the sum is: " << x + y;
}

// %%
summation(8,9)
// Out:
// the sum is: 17

// %%
summation(1 + 2, 3 * 4)
// Out:
// the sum is: 15

// %%
int multiply(int x, int y) // cannot use void because you will not be able to return a value
{
    return x * y;
}

// %%
multiply(3,4)
// Out:
// 12

// %%
int doubleNumber(int x)
{
    return x * 2;
}

// %%
doubleNumber(10)
// Out:
// 20

// %%
void printer(int x)
{
    std::cout << "the number is: " << x;
}

// %%
printer(doubleNumber(10))
// Out:
// the number is: 20
